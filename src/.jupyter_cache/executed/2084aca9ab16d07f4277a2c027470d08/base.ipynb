# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 7
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))


# reset state
# %reset

def ojs_define(**kwargs):
  import json
  from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# {"/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/importlib/_bootstrap.py": 1647338976.4783404, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/importlib/_bootstrap_external.py": 1647338976.482103, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/codecs.py": 1647338964.3530092, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/encodings/aliases.py": 1647338983.287878, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/encodings/__init__.py": 1647338983.283845, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/encodings/utf_8.py": 1647338984.4247696, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/encodings/latin_1.py": 1647338984.2951097, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/abc.py": 1647338964.2846549, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/io.py": 1647338964.4916904, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/stat.py": 1647338964.712451, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/_collections_abc.py": 1647338964.2398262, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/genericpath.py": 1647338964.4417272, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/posixpath.py": 1647338964.5961468, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/os.py": 1647338964.558697, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/_sitebuiltins.py": 1647338964.2694712, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/_bootlocale.py": 1647338964.233046, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/lib-dynload/_heapq.cpython-39-darwin.so": 1647338928.0, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/heapq.py": 1647338964.4701262, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/keyword.py": 1647338964.4994044, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/operator.py": 1647338964.5511832, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/reprlib.py": 1647338964.6390047, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/collections/__init__.py": 1647338982.5048952, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/types.py": 1647338964.7966206, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/functools.py": 1647338964.4383574, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/warnings.py": 1647338964.810579, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/importlib/__init__.py": 1647338976.4742925, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/importlib/machinery.py": 1647338976.4940271, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/collections/abc.py": 1647338982.5086362, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/contextlib.py": 1647338964.3704336, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/enum.py": 1647338964.4128773, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/sre_constants.py": 1647338964.7023418, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/sre_parse.py": 1647338964.7056851, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/sre_compile.py": 1647338964.6982598, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/copyreg.py": 1647338964.3811986, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/re.py": 1647338964.6356437, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/typing.py": 1647338964.800572, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/importlib/abc.py": 1647338976.4900863, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/importlib/util.py": 1647338976.5058463, "/Users/mfglabs/Library/Caches/pypoetry/virtualenvs/quarto-4nLyo31J-py3.9/lib/python3.9/site-packages/_virtualenv.py": 1653899493.0764356, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/site.py": 1647338964.675883, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/_weakrefset.py": 1647338964.2807875, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/weakref.py": 1647338964.8171766, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/pkgutil.py": 1647338964.5815697, "/Users/mfglabs/.pyenv/versions/3.9.7/lib/python3.9/runpy.py": 1647338964.6460924, "/Users/mfglabs/Library/Caches/pypoetry/virtuale ...
# /var/folders/by/3bf86pq91zd59zf28cf1r9w80000gn/T/ipykernel_91287/146381458.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display, Markdown

# %%
#| echo: true

# Load the train dataset
train = pd.read_csv('../data/train.csv')

# Build X_train and a y_train objects
X_train = train.drop(columns='label')
y_train = train['label']

# Reshape the data to an array of 28x28 images, dimensions expected by the model that will be built
X_train = np.array(X_train).reshape(-1,28,28,1)

# %%
display(Markdown("""
The shape of the train set is {shape}.
""".format(shape = X_train.shape)))
# Out:
# The shape of the train set is (42000, 28, 28, 1).

# %%
#| label: data-distrib
#| fig-cap: Distribution of digits in the trianing set

# Distribution of the digit in the train set
labels, counts = np.unique(y_train, return_counts=True)
plt.bar(labels, counts, align='center')
plt.xticks(list(range(0, 10)))
plt.xlabel('Digit')
plt.ylabel('Number of occurences');

# %%
#| label: 2plots
#| fig-cap: Preview of the training data
#| fig-subcap:
#|   - Distribution of digits in the training set
#|   - Example of digits
#| layout-ncol: 2

# Distribution of the digit in the train set
labels, counts = np.unique(y_train, return_counts=True)
plt.bar(labels, counts, align='center')
plt.xticks(list(range(0, 10)))
plt.xlabel('Digit')
plt.ylabel('Number of occurences')

# Glance at the data
count = 0
sample_size = 20
plt.figure(figsize=(16, 6))
for i in np.random.permutation(X_train.shape[0])[:sample_size]:
    count = count + 1
    plt.subplot(1, sample_size, count)
    plt.axhline("")
    plt.axvline("")
    plt.text(x=10, y=-10, s=y_train[i], fontsize=18, color="b")
    plt.imshow(X_train[i].reshape(28, 28), cmap=plt.cm.Greys)
plt.show()
